# %% [markdown]
# # Mengambil (Scrape) data ulasan dari aplikasi **MyTelkomsel** di Google Play Store.

# %%
# !pip install google-play-scraper

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
# Mengambil ulasan dari aplikasi MyTelkomsel dengan ID 'com.telkomsel.telkomselcm' di Google Play Store.
scrapreview = reviews_all(
    'com.telkomsel.telkomselcm', # ID aplikasi
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000
)

# %%
# Menyimpan ulasan dalam file CSV
import csv

with open('ulasan_myTelkomsel.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])
    for review in scrapreview:
        writer.writerow([review['content']])

# %%
import pandas as pd
app_reviews_df = pd.DataFrame(scrapreview)

# %%
app_reviews_df.to_csv('ulasan_myTelkomsel.csv', index=False)

# %%
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df
# Out:
#                                     reviewId         userName  \
# 0       09be6946-41fa-4000-bb42-fb7e43577edd  Pengguna Google
# 1       b4c06948-0012-4099-b635-04ca3e6778e0  Pengguna Google
# 2       760ed5e8-2955-4581-b46c-df075222e149  Pengguna Google
# 3       7e152e4f-a9bb-4e67-82d4-2fabf7747b35  Pengguna Google
# 4       adaba360-10fb-45da-9457-ed751f5daef2  Pengguna Google
# ...                                      ...              ...
# 112495  bf602a59-b43c-4f16-9f04-a8d08071a6ac  Pengguna Google
# 112496  ff30ef63-87f2-411a-aa11-8e59093ae2ec  Pengguna Google
# 112497  a5c9c620-0754-4458-8c83-8eb3a5efb760  Pengguna Google
# 112498  44ed5e80-f1ba-402c-ba06-956a562bf59b  Pengguna Google
# 112499  f2448c48-d595-40bb-b231-0ba097456ba1  Pengguna Google
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
app_reviews_df.sample(5)
# Out:
#                                     reviewId         userName  \
# 22716   9628cba2-84b6-44b4-af6b-e3f926cd0c6b  Pengguna Google
# 111570  c43c2e1d-baa3-4a14-9e7f-c0f194a59200  Pengguna Google
# 8378    0dc83539-29af-4690-8363-fd1e1f49fe9b  Pengguna Google
# 69388   42bfbd07-6f16-4583-bea4-a158f94454c2  Pengguna Google
# 66344   2209ada2-4da9-43b0-8661-5e036731d048  Pengguna Google
#
#                                                 userImage  \
# 22716   https://play-lh.googleusercontent.com/EGemoI2N...
# 111570  https://play-lh.googleusercontent.com/EGemoI2N...
# 8378    https://play-lh.googleusercontent.com/EGemoI2N...
# 69388   https://play-lh.googleusercontent.com/EGemoI2N...
# 66344   https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 22716   Kesalahan terbesar pembuat aplikasi adalah tid...      2
# 111570  Apps nya bagus cuman paketannya sering2 beruba...      5
# ...
